# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("responses.csv")

# %%
df.head(10)
# Out:
#             Timestamp  Roll Number  B.Tech. [CEO-325 CPM & PERT]  \
# 0  1/10/2019 22:44:32        16545                             1
# 1  1/10/2019 22:45:08        16555                            12
# 2  1/10/2019 22:45:12        16577                             1
# 3  1/10/2019 22:45:38        16544                             1
# 4  1/10/2019 22:46:17        16578                             1
# 5  1/10/2019 22:55:36        16213                             4
#
#    B.Tech. [EEO-325 (b) Optimization Techniques]  \
# 0                                              2
# 1                                              1
# 2                                              2
# 3                                              3
# 4                                              2
# 5                                              3
#
#    B.Tech. [MEO-325 Modelling and Simulation]  \
# 0                                           3
# 1                                           2
# 2                                           3
# 3                                           2
# 4                                           5
# 5                                           1
#
#    B.Tech. [MEO -325 (a) Robotics]  \
# 0                                4
# 1                                3
# 2                                4
# 3                                4
# 4                                4
# 5                                2
#
#    B.Tech. [ECO-325 (a) MEMS and Sensor Design]  \
# 0                                             5
# 1                                             4
# 2                                             5
# 3                                             5
# 4                                             3
# 5                                             5
#
#    B.Tech. [ECO-325 (b) Telecommunication System]  \
# 0                                               6
# 1                                               5
# 2                                               6
# 3                                               6
# 4                                               6
# 5                                               6
#
#    B.Tech. [CSO-324 Computer Graphics]  \
# 0                                    7
# 1                                    6
# 2                                    7
# 3                                    7
# 4                                    7
# 5                                    7
#
#    B.Tech. [HUO-325 Dynamics of Behavioural Science in Industries]  \
# 0                                                  8
# 1                                                  7
# 2                                                  8
# 3                                                  8
# 4                                                  8
# 5                                                  8
#
#    B.Tech. [CMO-320 (e) Bionanotechnology]  \
# 0                                        9
# 1                                        8
# 2                                        9
# 3                                        9
# 4                                        9
# 5                                        9
#
#    B.Tech. [MAO-325(b) Statistical Testing and Quality Control]  \
# 0                                                 10
# 1                                                  9
# 2                                                 10
# 3                                                 10
# 4                                                 11
# 5                                                 10
#
#    B.Tech. [MSO-326(a) Nanomaterials & Technology]  \
# 0                                               11
# 1                                               10
# 2                                               11
# 3                                               11
# 4                                               10
# 5                                               11
#
#    B.Tech. [ENO-326 Energy & Environment]
# 0                                      12
# 1                                      11
# 2                                      12
# 3                                      12
# 4                                      12
# 5                                      12

# %%
df=df.drop("Timestamp",axis=1)

# %%
df.columns.str.split('[').str[1].str.split(']').str[0]
# Out:
# Index([                                                    nan,
#                                           'CEO-325 CPM & PERT',
#                          'EEO-325 (b) Optimization Techniques',
#                             'MEO-325 Modelling and Simulation',
#                                        'MEO -325 (a) Robotics',
#                           'ECO-325 (a) MEMS and Sensor Design',
#                         'ECO-325 (b) Telecommunication System',
#                                    'CSO-324 Computer Graphics',
#        'HUO-325 Dynamics of Behavioural Science in Industries',
#                                'CMO-320 (e) Bionanotechnology',
#           'MAO-325(b) Statistical Testing and Quality Control',
#                        'MSO-326(a) Nanomaterials & Technology',
#                                 'ENO-326 Energy & Environment'],
#       dtype='object')

# %%
rk = pd.read_csv('rank.csv',header=None)

# %%
rk.head(10)
# Out:
#        0  1
# 0  16545  2
# 1  16555  3
# 2  16577  1
# 3  16544  4
# 4  16578  5
# 5  16213  6

# %%
rk=rk.sort_values(by=[1])

# %%
for index, row in rk.iterrows():
    for ind,r in df.iterrows():
        print()
# Out:
# 16545
# 16555
# 1
# 16544
# 16578
# 16213
# 1
# 16555
# 16577
# 16544
# 16578
# 16213
# 16545
# 12
# 16577
# 16544
# 16578
# 16213
# 16545
# 16555
# 16577
# 1
# 16578
# 16213
# 16545
# 16555
# 16577
# 16544
# 1
# 16213
# 16545
# 16555
# 16577
# 16544
# 16578
# 4
